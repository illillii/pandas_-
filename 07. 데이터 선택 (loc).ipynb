# %% [markdown]
# # 7. 데이터 선택 (loc)
# 이름을 이용하여 원하는 row 에서 원하는 col 선택

# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.loc['1번'] # index 1번에 해당하는 전체 데이터
# Out:
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
df.loc['5번'] # index 5번에 해당하는 전체 데이터
# Out:
# 이름      강백호
# 학교      북산고
# 키       188
# 국어       15
# 영어       20
# 수학       10
# 과학       35
# 사회       10
# SW특기    NaN
# Name: 5번, dtype: object

# %%
df.loc['1번', '국어'] # index 1번에 해당하는 국어 데이터
# Out:
# 90

# %%
df.loc[['1번', '2번'], '영어'] # index 1번, 2번에 해당하는 영어 데이터
# Out:
# 지원번호
# 1번    85
# 2번    35
# Name: 영어, dtype: int64

# %%
df.loc[['1번', '2번'], ['영어', '수학']] # index 1번, 2번에 해당하는 영어, 수학 데이터
# Out:
#       영어   수학
# 지원번호
# 1번    85  100
# 2번    35   50

# %%
df.loc['1번':'5번', '국어':'사회'] # index 1번부터 5번까지, 국어부터 사회까지 데이터
# Out:
#       국어  영어   수학  과학  사회
# 지원번호
# 1번    90  85  100  95  85
# 2번    40  35   50  55  25
# 3번    80  75   70  80  75
# 4번    40  60   70  75  80
# 5번    15  20   10  35  10

# %% [markdown]
# # 7. 데이터 선택 (loc)
# 데이서 선택 (loc) 요리조리

# %%
import pandas as pd
df1 = pd.read_excel('교육부_통합합급 현황.xlsx', index_col='시도교육청')
df1
# Out:
#                      지역교육청           지역    정보공시학교코드              학교명  학교급코드  \
# 시도교육청
# 서울특별시교육청               교육부    서울특별시 서초구  S000003511    서울교육대학교부설초등학교      2
# 서울특별시교육청               교육부    서울특별시 종로구  S000003563  서울대학교사범대학부설초등학교      2
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구  S010000738         서울개일초등학교      2
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구  S010000741         서울구룡초등학교      2
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구  S010000742         서울논현초등학교      2
# ...                    ...          ...         ...              ...    ...
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000801           월랑초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000834           이도초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000836           도련초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000837           삼화초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000839          하귀일초등학교      2
#
# ...

# %%
df2 = pd.read_excel('교육부_특수교육정보 특수학교 현황_20190924.xlsx', index_col='설립별')
df2
# Out:
#       장애별  학교 수  장애영아 학급 수  유치원 장애영아 학급 수  초등학교 장애영아 학급 수  중학교 장애영아 학급 수  \
# 설립별
# 국립   시각장애     1          2              4               7              8
# 국립   청각장애     1          3              4               6             10
# 국립   지적장애     1          0              1              12              6
# 국립   지체장애     1          0              3              14              8
# 국립   정서장애     1          0              3              12              6
# 공립   시각장애     2          0              3               9              6
# 공립   청각장애     3          3              7              18              9
# 공립   지적장애    63          3             67             621            502
# 공립   지체장애     5          2              7              74             54
# 공립   정서장애     1          0              2               9              7
# 사립   시각장애     9          1             10              54             30
# 사립   청각장애    10         11             23              62             45
# ...

# %%
df3 = pd.read_excel('장애영역별특수학급학생수집계현황.xlsx', index_col='기준년도')
df3
# Out:
#        장애영역명  총학생수(명)  유치원전체학생수(명)  유치원3세학생수(명)  유치원4세학생수(명)  유치원5세이상학생수(명)  \
# 기준년도
# 2022    건강장애       10            2            0            0              2
# 2022    발달지체     1399          893          189          348            356
# 2022    시각장애       67            3            0            3              0
# 2022  의사소통장애      381           60            5           14             41
# 2022   자폐성장애     2991          306           49          111            146
# ...      ...      ...          ...          ...          ...            ...
# 2012  정서행동장애      313            4            0            2              2
# 2012    지적장애     7328           83            8           27             48
# 2012    지체장애     1394           65           15           19             31
# 2012    청각장애      206           11            2            3              6
# 2012    학습장애      443            0            0            0              0
#
# ...

# %%
df4 = pd.read_excel('장애인 편의시설 현황(초).xlsx', index_col='시도교육청')
df4
# Out:
#                      지역교육청           지역    정보공시학교코드              학교명  학교급코드  \
# 시도교육청
# 서울특별시교육청               교육부    서울특별시 서초구  S000003511    서울교육대학교부설초등학교      2
# 서울특별시교육청               교육부    서울특별시 종로구  S000003563  서울대학교사범대학부설초등학교      2
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구  S010000738         서울개일초등학교      2
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구  S010000741         서울구룡초등학교      2
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구  S010000742         서울논현초등학교      2
# ...                    ...          ...         ...              ...    ...
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000801           월랑초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000834           이도초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000836           도련초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000837           삼화초등학교      2
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000839          하귀일초등학교      2
#
# ...

# %%
df1.loc['서울특별시교육청']
# Out:
#                    지역교육청         지역    정보공시학교코드              학교명  학교급코드 설립구분  \
# 시도교육청
# 서울특별시교육청             교육부  서울특별시 서초구  S000003511    서울교육대학교부설초등학교      2   국립
# 서울특별시교육청             교육부  서울특별시 종로구  S000003563  서울대학교사범대학부설초등학교      2   국립
# 서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000738         서울개일초등학교      2   공립
# 서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000741         서울구룡초등학교      2   공립
# 서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000742         서울논현초등학교      2   공립
# ...                  ...        ...         ...              ...    ...  ...
# 서울특별시교육청    서울특별시남부교육지원청  서울특별시 구로구  S010006431        서울하늘숲초등학교      2   공립
# 서울특별시교육청    서울특별시남부교육지원청  서울특별시 구로구  S010006432         서울항동초등학교      2   공립
# 서울특별시교육청  서울특별시강동송파교육지원청  서울특별시 송파구  S010006433        서울해누리초등학교      2   공립
# 서울특별시교육청    서울특별시동부교육지원청  서울특별시 중랑구  S010006476        서울양원숲초등학교      2   공립
# 서울특별시교육청  서울특별시강동송파교육지원청  서울특별시 강동구  S010006543         서울강빛초등학교      2   공립
#
# ...

# %%
df2.loc['국립']
# Out:
#       장애별  학교 수  장애영아 학급 수  유치원 장애영아 학급 수  초등학교 장애영아 학급 수  중학교 장애영아 학급 수  \
# 설립별
# 국립   시각장애     1          2              4               7              8
# 국립   청각장애     1          3              4               6             10
# 국립   지적장애     1          0              1              12              6
# 국립   지체장애     1          0              3              14              8
# 국립   정서장애     1          0              3              12              6
#
#      고등학교 장애영아 학급 수  전공과 장애영아 학급 수  장애영아 학생 수  유치원 학생 수  초등학교 학생 수  중학교 학생 수  \
# 설립별
# 국립               11              7          6        17         20        33
# 국립               11              0          7         6         14        30
# 국립                6              5          0         2         70        36
# 국립               10              4          0        10         60        32
# 국립                6              6          0         9         58        36
#
#      고등학교 학생 수  전공과 학생 수
# 설립별
# ...

# %%
df3.loc[2022]
# Out:
#        장애영역명  총학생수(명)  유치원전체학생수(명)  유치원3세학생수(명)  유치원4세학생수(명)  유치원5세이상학생수(명)  \
# 기준년도
# 2022    건강장애       10            2            0            0              2
# 2022    발달지체     1399          893          189          348            356
# 2022    시각장애       67            3            0            3              0
# 2022  의사소통장애      381           60            5           14             41
# 2022   자폐성장애     2991          306           49          111            146
# 2022  정서행동장애      273            0            0            0              0
# 2022    지적장애     9571          165           17           42            106
# 2022    지체장애     1176          165           45           53             67
# 2022    청각장애      183           17            2           10              5
# 2022    학습장애      141            0            0            0              0
#
#       초등학교전체학생수(명)  초등학교1학년학생수(명)  초등학교2학년학생수(명)  초등학교3학년학생수(명)  ...  \
# ...

# %%
df4.loc['서울특별시교육청']
# Out:
#                    지역교육청         지역    정보공시학교코드              학교명  학교급코드 설립구분  \
# 시도교육청
# 서울특별시교육청             교육부  서울특별시 서초구  S000003511    서울교육대학교부설초등학교      2   국립
# 서울특별시교육청             교육부  서울특별시 종로구  S000003563  서울대학교사범대학부설초등학교      2   국립
# 서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000738         서울개일초등학교      2   공립
# 서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000741         서울구룡초등학교      2   공립
# 서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구  S010000742         서울논현초등학교      2   공립
# ...                  ...        ...         ...              ...    ...  ...
# 서울특별시교육청    서울특별시남부교육지원청  서울특별시 구로구  S010006431        서울하늘숲초등학교      2   공립
# 서울특별시교육청    서울특별시남부교육지원청  서울특별시 구로구  S010006432         서울항동초등학교      2   공립
# 서울특별시교육청  서울특별시강동송파교육지원청  서울특별시 송파구  S010006433        서울해누리초등학교      2   공립
# 서울특별시교육청    서울특별시동부교육지원청  서울특별시 중랑구  S010006476        서울양원숲초등학교      2   공립
# 서울특별시교육청  서울특별시강동송파교육지원청  서울특별시 강동구  S010006543         서울강빛초등학교      2   공립
#
# ...

# %%
df1.loc['서울특별시교육청', '지역교육청']
# Out:
# 시도교육청
# 서울특별시교육청               교육부
# 서울특별시교육청               교육부
# 서울특별시교육청    서울특별시강남서초교육지원청
# 서울특별시교육청    서울특별시강남서초교육지원청
# 서울특별시교육청    서울특별시강남서초교육지원청
#                  ...
# 서울특별시교육청      서울특별시남부교육지원청
# 서울특별시교육청      서울특별시남부교육지원청
# 서울특별시교육청    서울특별시강동송파교육지원청
# 서울특별시교육청      서울특별시동부교육지원청
# 서울특별시교육청    서울특별시강동송파교육지원청
# Name: 지역교육청, Length: 605, dtype: object

# %%
df2.loc['국립', '장애별']
# Out:
# 설립별
# 국립    시각장애
# 국립    청각장애
# 국립    지적장애
# 국립    지체장애
# 국립    정서장애
# Name: 장애별, dtype: object

# %%
df3.loc[2022, '장애영역명']
# Out:
# 기준년도
# 2022      건강장애
# 2022      발달지체
# 2022      시각장애
# 2022    의사소통장애
# 2022     자폐성장애
# 2022    정서행동장애
# 2022      지적장애
# 2022      지체장애
# 2022      청각장애
# 2022      학습장애
# Name: 장애영역명, dtype: object

# %%
df4.loc['서울특별시교육청', '지역교육청']
# Out:
# 시도교육청
# 서울특별시교육청               교육부
# 서울특별시교육청               교육부
# 서울특별시교육청    서울특별시강남서초교육지원청
# 서울특별시교육청    서울특별시강남서초교육지원청
# 서울특별시교육청    서울특별시강남서초교육지원청
#                  ...
# 서울특별시교육청      서울특별시남부교육지원청
# 서울특별시교육청      서울특별시남부교육지원청
# 서울특별시교육청    서울특별시강동송파교육지원청
# 서울특별시교육청      서울특별시동부교육지원청
# 서울특별시교육청    서울특별시강동송파교육지원청
# Name: 지역교육청, Length: 605, dtype: object

# %%
df1.loc[['서울특별시교육청', '제주특별자치도교육청'], '지역교육청']
# Out:
# 시도교육청
# 서울특별시교육청                 교육부
# 서울특별시교육청                 교육부
# 서울특별시교육청      서울특별시강남서초교육지원청
# 서울특별시교육청      서울특별시강남서초교육지원청
# 서울특별시교육청      서울특별시강남서초교육지원청
#                    ...
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# Name: 지역교육청, Length: 723, dtype: object

# %%
df2.loc[['국립', '공립'], '장애별']
# Out:
# 설립별
# 국립    시각장애
# 국립    청각장애
# 국립    지적장애
# 국립    지체장애
# 국립    정서장애
# 공립    시각장애
# 공립    청각장애
# 공립    지적장애
# 공립    지체장애
# 공립    정서장애
# Name: 장애별, dtype: object

# %%
df3.loc[[2022, 2021], '장애영역명']
# Out:
# 기준년도
# 2022      건강장애
# 2022      발달지체
# 2022      시각장애
# 2022    의사소통장애
# 2022     자폐성장애
# 2022    정서행동장애
# 2022      지적장애
# 2022      지체장애
# 2022      청각장애
# 2022      학습장애
# 2021      건강장애
# 2021      발달지체
# 2021      시각장애
# 2021    의사소통장애
# 2021     자폐성장애
# 2021    정서행동장애
# 2021      지적장애
# 2021      지체장애
# 2021      청각장애
# 2021      학습장애
# Name: 장애영역명, dtype: object

# %%
df4.loc[['서울특별시교육청', '제주특별자치도교육청'], '지역교육청']
# Out:
# 시도교육청
# 서울특별시교육청                 교육부
# 서울특별시교육청                 교육부
# 서울특별시교육청      서울특별시강남서초교육지원청
# 서울특별시교육청      서울특별시강남서초교육지원청
# 서울특별시교육청      서울특별시강남서초교육지원청
#                    ...
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# 제주특별자치도교육청          제주시교육지원청
# Name: 지역교육청, Length: 723, dtype: object

# %%
df1.loc[['서울특별시교육청', '제주특별자치도교육청'], ['지역교육청', '지역']]
# Out:
#                      지역교육청           지역
# 시도교육청
# 서울특별시교육청               교육부    서울특별시 서초구
# 서울특별시교육청               교육부    서울특별시 종로구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# ...                    ...          ...
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
#
# [723 rows x 2 columns]

# %%
df2.loc[['국립', '공립'], ['장애별', '학교 수']]
# Out:
#       장애별  학교 수
# 설립별
# 국립   시각장애     1
# 국립   청각장애     1
# 국립   지적장애     1
# 국립   지체장애     1
# 국립   정서장애     1
# 공립   시각장애     2
# 공립   청각장애     3
# 공립   지적장애    63
# 공립   지체장애     5
# 공립   정서장애     1

# %%
df3.loc[[2022, 2021], ['장애영역명', '총학생수(명)']]
# Out:
#        장애영역명  총학생수(명)
# 기준년도
# 2022    건강장애       10
# 2022    발달지체     1399
# 2022    시각장애       67
# 2022  의사소통장애      381
# 2022   자폐성장애     2991
# 2022  정서행동장애      273
# 2022    지적장애     9571
# 2022    지체장애     1176
# 2022    청각장애      183
# 2022    학습장애      141
# 2021    건강장애       15
# 2021    발달지체     1079
# 2021    시각장애       76
# 2021  의사소통장애      362
# 2021   자폐성장애     2569
# 2021  정서행동장애      281
# 2021    지적장애     8965
# 2021    지체장애     1162
# 2021    청각장애      196
# 2021    학습장애       31

# %%
df4.loc[['서울특별시교육청', '제주특별자치도교육청'], ['지역교육청', '지역']]
# Out:
#                      지역교육청           지역
# 시도교육청
# 서울특별시교육청               교육부    서울특별시 서초구
# 서울특별시교육청               교육부    서울특별시 종로구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# ...                    ...          ...
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
#
# [723 rows x 2 columns]

# %%
df1.loc['서울특별시교육청':'제주특별자치도교육청', '지역교육청':'지역']
# Out:
#                      지역교육청           지역
# 시도교육청
# 서울특별시교육청               교육부    서울특별시 서초구
# 서울특별시교육청               교육부    서울특별시 종로구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# ...                    ...          ...
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
#
# [6309 rows x 2 columns]

# %%
df2.loc['국립':'공립', '장애별':'학교 수']
# Out:
#       장애별  학교 수
# 설립별
# 국립   시각장애     1
# 국립   청각장애     1
# 국립   지적장애     1
# 국립   지체장애     1
# 국립   정서장애     1
# 공립   시각장애     2
# 공립   청각장애     3
# 공립   지적장애    63
# 공립   지체장애     5
# 공립   정서장애     1

# %%
df3.loc[2022:2021, '장애영역명':'총학생수(명)']
# Out:
#        장애영역명  총학생수(명)
# 기준년도
# 2022    건강장애       10
# 2022    발달지체     1399
# 2022    시각장애       67
# 2022  의사소통장애      381
# 2022   자폐성장애     2991
# 2022  정서행동장애      273
# 2022    지적장애     9571
# 2022    지체장애     1176
# 2022    청각장애      183
# 2022    학습장애      141
# 2021    건강장애       15
# 2021    발달지체     1079
# 2021    시각장애       76
# 2021  의사소통장애      362
# 2021   자폐성장애     2569
# 2021  정서행동장애      281
# 2021    지적장애     8965
# 2021    지체장애     1162
# 2021    청각장애      196
# 2021    학습장애       31

# %%
df4.loc['서울특별시교육청':'제주특별자치도교육청', '지역교육청':'지역']
# Out:
#                      지역교육청           지역
# 시도교육청
# 서울특별시교육청               교육부    서울특별시 서초구
# 서울특별시교육청               교육부    서울특별시 종로구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# 서울특별시교육청    서울특별시강남서초교육지원청    서울특별시 강남구
# ...                    ...          ...
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
# 제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시
#
# [6309 rows x 2 columns]
